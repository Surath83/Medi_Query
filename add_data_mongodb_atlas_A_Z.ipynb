# %%
#python -m pip install "pymongo[srv]"
#conn: "mongodb+srv://<>:<>@medicines.fcj01tp.mongodb.net/?retryWrites=true&w=majority&appName=medicines"

#<GCP>

#(@admin)
#user: surath172003_db_user
#pass: 5xgLEFjskThzX6Jr


#(read/write)      //All Resources
#user: med_data 
#pass: Vg6iZRzxGpBoj3WP


#(read)            //medicines cluster
#user: root 
#pass: root

# %%
# %pip install pymongo

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://med_data:Vg6iZRzxGpBoj3WP@medicines.fcj01tp.mongodb.net/?retryWrites=true&w=majority&appName=medicines"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.1-cp312-cp312-win_amd64.whl (910 kB)
#    ---------------------------------------- 0.0/910.6 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/910.6 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 910.6/910.6 kB 2.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.1
# Note: you may need to restart the kernel to use updated packages.
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

# %%
df = pd.read_csv("./Extensive_A_Z_medicines_dataset_of_India.csv")
df.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  Augmentin 625 Duo Tablet    223.42            False
# 1   2       Azithral 500 Tablet    132.36            False
# 2   3          Ascoril LS Syrup    118.00            False
# 3   4      Allegra 120mg Tablet    218.81            False
# 4   4      Allegra 120mg Tablet    218.81            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 10 tablets
#
#       short_composition1          short_composition2  \
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# 1   Azithromycin (500mg)                         NaN
# 2   Ambroxol (30mg/5ml)    Levosalbutamol (1mg/5ml)
# 3   Fexofenadine (120mg)                         NaN
# 4   Fexofenadine (120mg)                         NaN
#
#                       substitute0  ...  \
# 0  Penciclav 500 mg/125 mg Tablet  ...
# 1         Zithrocare 500mg Tablet  ...
# 2                 Solvin LS Syrup  ...
# 3                    Lcfex Tablet  ...
# 4                    Lcfex Tablet  ...
#
#                            Consolidated_Side_Effects  \
# 0                         Vomiting, Nausea, Diarrhea
# 1         Vomiting, Nausea, Abdominal pain, Diarrhea
# 2  Nausea, Vomiting, Diarrhea, Upset stomach, Sto...
# 3            Headache, Drowsiness, Dizziness, Nausea
# 4            Headache, Drowsiness, Dizziness, Nausea
#
#                                                 use0  \
# 0                  Treatment of Bacterial infections
# 1                  Treatment of Bacterial infections
# 2                      Treatment of Cough with mucus
# 3  Treatment of Sneezing and runny nose due to al...
# 4  Treatment of Sneezing and runny nose due to al...
#
#                                use1 use2 use3 use4  \
# 0                               NaN  NaN  NaN  NaN
# 1                               NaN  NaN  NaN  NaN
# 2                               NaN  NaN  NaN  NaN
# 3  Treatment of Allergic conditions  NaN  NaN  NaN
# 4  Treatment of Allergic conditions  NaN  NaN  NaN
#
#                Chemical Class Habit Forming Therapeutic Class  \
# 0                         NaN            No   ANTI INFECTIVES
# 1                  Macrolides            No   ANTI INFECTIVES
# 2                         NaN            No       RESPIRATORY
# 3  Diphenylmethane Derivative            No       RESPIRATORY
# 4  Diphenylmethane Derivative            No       RESPIRATORY
#
#                              Action Class
# 0                                     NaN
# 1                              Macrolides
# 2                                     NaN
# 3  H1 Antihistaminics (second Generation)
# 4  H1 Antihistaminics (second Generation)
#
# [5 rows x 24 columns]

# %%
# Columns to remove
cols_to_drop = [
    "Is_discontinued",
    "substitute0",
    "substitute1",
    "substitute2",
    "substitute3",
    "substitute4"
]

# Drop the columns
df_cleaned = df.drop(columns=cols_to_drop, errors="ignore")

# Save cleaned dataset
df_cleaned.to_csv("medicines_cleaned.csv", index=False)

print("✅ Cleaning done! Saved as medicines_cleaned.csv")
df_cleaned.head()
# Out:
# ✅ Cleaning done! Saved as medicines_cleaned.csv
#    id                      name  price(₹)  \
# 0   1  Augmentin 625 Duo Tablet    223.42
# 1   2       Azithral 500 Tablet    132.36
# 2   3          Ascoril LS Syrup    118.00
# 3   4      Allegra 120mg Tablet    218.81
# 4   4      Allegra 120mg Tablet    218.81
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 10 tablets
#
#       short_composition1          short_composition2  \
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# 1   Azithromycin (500mg)                         NaN
# 2   Ambroxol (30mg/5ml)    Levosalbutamol (1mg/5ml)
# 3   Fexofenadine (120mg)                         NaN
# 4   Fexofenadine (120mg)                         NaN
#
#                            Consolidated_Side_Effects  \
# 0                         Vomiting, Nausea, Diarrhea
# 1         Vomiting, Nausea, Abdominal pain, Diarrhea
# 2  Nausea, Vomiting, Diarrhea, Upset stomach, Sto...
# 3            Headache, Drowsiness, Dizziness, Nausea
# 4            Headache, Drowsiness, Dizziness, Nausea
#
#                                                 use0  \
# 0                  Treatment of Bacterial infections
# 1                  Treatment of Bacterial infections
# 2                      Treatment of Cough with mucus
# 3  Treatment of Sneezing and runny nose due to al...
# 4  Treatment of Sneezing and runny nose due to al...
#
#                                use1 use2 use3 use4  \
# 0                               NaN  NaN  NaN  NaN
# 1                               NaN  NaN  NaN  NaN
# 2                               NaN  NaN  NaN  NaN
# 3  Treatment of Allergic conditions  NaN  NaN  NaN
# 4  Treatment of Allergic conditions  NaN  NaN  NaN
#
#                Chemical Class Habit Forming Therapeutic Class  \
# 0                         NaN            No   ANTI INFECTIVES
# 1                  Macrolides            No   ANTI INFECTIVES
# 2                         NaN            No       RESPIRATORY
# 3  Diphenylmethane Derivative            No       RESPIRATORY
# 4  Diphenylmethane Derivative            No       RESPIRATORY
#
#                              Action Class
# 0                                     NaN
# 1                              Macrolides
# 2                                     NaN
# 3  H1 Antihistaminics (second Generation)
# 4  H1 Antihistaminics (second Generation)

# %%
df = pd.read_csv("medicines_cleaned.csv")

# Replace empty strings, whitespace-only strings, and NaN with None
df = df.applymap(lambda x: None if (pd.isna(x) or str(x).strip() == "") else x)

# Save the modified dataset
df.to_csv("medicines_cleaned_filled.csv", index=False)

print("✅ Empty cells replaced with None. Saved as medicines_cleaned_filled.csv")
df.head(10)
# Out:
# C:\Users\surat\AppData\Local\Temp\ipykernel_16088\4089483627.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if (pd.isna(x) or str(x).strip() == "") else x)
# ✅ Empty cells replaced with None. Saved as medicines_cleaned_filled.csv
#    id                      name  price(₹)  \
# 0   1  Augmentin 625 Duo Tablet    223.42
# 1   2       Azithral 500 Tablet    132.36
# 2   3          Ascoril LS Syrup    118.00
# 3   4      Allegra 120mg Tablet    218.81
# 4   4      Allegra 120mg Tablet    218.81
# 5   5            Avil 25 Tablet     10.96
# 6   6          Allegra-M Tablet    241.48
# 7   7      Amoxyclav 625 Tablet    223.27
# 8   8           Azee 500 Tablet    132.38
# 9   9        Atarax 25mg Tablet     85.50
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 5                     Sanofi India  Ltd  allopathy     strip of 15 tablets
# 6                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 7                                Abbott  allopathy     strip of 10 tablets
# 8                             Cipla Ltd  allopathy      strip of 5 tablets
# 9           Dr Reddy's Laboratories Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2  \
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# 1   Azithromycin (500mg)                        None
# 2   Ambroxol (30mg/5ml)    Levosalbutamol (1mg/5ml)
# 3   Fexofenadine (120mg)                        None
# 4   Fexofenadine (120mg)                        None
# 5     Pheniramine (25mg)                        None
# 6    Montelukast (10mg)         Fexofenadine (120mg)
# 7  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# 8   Azithromycin (500mg)                        None
# 9     Hydroxyzine (25mg)                        None
#
#                            Consolidated_Side_Effects  \
# 0                         Vomiting, Nausea, Diarrhea
# 1         Vomiting, Nausea, Abdominal pain, Diarrhea
# 2  Nausea, Vomiting, Diarrhea, Upset stomach, Sto...
# 3            Headache, Drowsiness, Dizziness, Nausea
# 4            Headache, Drowsiness, Dizziness, Nausea
# 5                       Sleepiness, Dryness in mouth
# 6  Nausea, Diarrhea, Vomiting, Skin rash, Flu-lik...
# 7                         Vomiting, Nausea, Diarrhea
# 8         Vomiting, Nausea, Abdominal pain, Diarrhea
# 9  Sedation, Nausea, Vomiting, Upset stomach, Con...
#
#                                                 use0  \
# 0                  Treatment of Bacterial infections
# 1                  Treatment of Bacterial infections
# 2                      Treatment of Cough with mucus
# 3  Treatment of Sneezing and runny nose due to al...
# 4  Treatment of Sneezing and runny nose due to al...
# 5                   Treatment of Allergic conditions
# 6  Treatment of Sneezing and runny nose due to al...
# 7                  Treatment of Bacterial infections
# 8                  Treatment of Bacterial infections
# 9                               Treatment of Anxiety
#
#                                                 use1  use2  use3  use4  \
# 0                                               None  None  None  None
# 1                                               None  None  None  None
# 2                                               None  None  None  None
# 3                   Treatment of Allergic conditions  None  None  None
# 4                   Treatment of Allergic conditions  None  None  None
# 5                                               None  None  None  None
# 6                                               None  None  None  None
# 7                                               None  None  None  None
# 8                                               None  None  None  None
# 9  Treatment of Skin conditions with inflammation...  None  None  None
#
#                Chemical Class Habit Forming Therapeutic Class  \
# 0                        None            No   ANTI INFECTIVES
# 1                  Macrolides            No   ANTI INFECTIVES
# 2                        None            No       RESPIRATORY
# 3  Diphenylmethane Derivative            No       RESPIRATORY
# 4  Diphenylmethane Derivative            No       RESPIRATORY
# 5       Pyridines Derivatives            No       RESPIRATORY
# 6                        None            No       RESPIRATORY
# 7                        None            No   ANTI INFECTIVES
# 8                  Macrolides            No   ANTI INFECTIVES
# 9       Piperazine Derivative            No       RESPIRATORY
#
#                              Action Class
# 0                                    None
# 1                              Macrolides
# 2                                    None
# 3  H1 Antihistaminics (second Generation)
# 4  H1 Antihistaminics (second Generation)
# 5   H1 Antihistaminics (First Generation)
# 6                                    None
# 7                                    None
# 8                              Macrolides
# 9   H1 Antihistaminics (First Generation)

# %%
list_of_dicts = df.to_dict(orient='records')
list_of_dicts
# Out:
# [{'id': 1,
#   'name': 'Augmentin 625 Duo Tablet',
#   'price(₹)': 223.42,
#   'manufacturer_name': 'Glaxo SmithKline Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Amoxycillin  (500mg) ',
#   'short_composition2': '  Clavulanic Acid (125mg)',
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': None},
#  {'id': 2,
#   'name': 'Azithral 500 Tablet',
#   'price(₹)': 132.36,
#   'manufacturer_name': 'Alembic Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 5 tablets',
#   'short_composition1': 'Azithromycin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 3,
#   'name': 'Ascoril LS Syrup',
#   'price(₹)': 118.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Ambroxol (30mg/5ml) ',
#   'short_composition2': ' Levosalbutamol (1mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Diarrhea, Upset stomach, Stomach pain, Allergic reaction, Dizziness, Headache, Rash, Hives, Tremors, Palpitations, Muscle cramp, Increased heart rate',
#   'use0': 'Treatment of Cough with mucus',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 4,
#   'name': 'Allegra 120mg Tablet',
#   'price(₹)': 218.81,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Fexofenadine (120mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Drowsiness, Dizziness, Nausea',
#   'use0': 'Treatment of Sneezing and runny nose due to allergies',
#   'use1': 'Treatment of Allergic conditions',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Diphenylmethane Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (second Generation)'},
#  {'id': 4,
#   'name': 'Allegra 120mg Tablet',
#   'price(₹)': 218.81,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Fexofenadine (120mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Drowsiness, Dizziness, Nausea',
#   'use0': 'Treatment of Sneezing and runny nose due to allergies',
#   'use1': 'Treatment of Allergic conditions',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Diphenylmethane Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (second Generation)'},
#  {'id': 5,
#   'name': 'Avil 25 Tablet',
#   'price(₹)': 10.96,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Pheniramine (25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sleepiness, Dryness in mouth',
#   'use0': 'Treatment of Allergic conditions',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Pyridines Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 6,
#   'name': 'Allegra-M Tablet',
#   'price(₹)': 241.48,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Montelukast (10mg) ',
#   'short_composition2': ' Fexofenadine (120mg)',
#   'Consolidated_Side_Effects': 'Nausea, Diarrhea, Vomiting, Skin rash, Flu-like symptoms, Headache, Drowsiness, Dizziness',
#   'use0': 'Treatment of Sneezing and runny nose due to allergies',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 7,
#   'name': 'Amoxyclav 625 Tablet',
#   'price(₹)': 223.27,
#   'manufacturer_name': 'Abbott',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Amoxycillin  (500mg) ',
#   'short_composition2': '  Clavulanic Acid (125mg)',
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': None},
#  {'id': 8,
#   'name': 'Azee 500 Tablet',
#   'price(₹)': 132.38,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 5 tablets',
#   'short_composition1': 'Azithromycin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 9,
#   'name': 'Atarax 25mg Tablet',
#   'price(₹)': 85.5,
#   'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Hydroxyzine (25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sedation, Nausea, Vomiting, Upset stomach, Constipation',
#   'use0': 'Treatment of Anxiety',
#   'use1': 'Treatment of Skin conditions with inflammation & itching',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Piperazine Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 10,
#   'name': 'Ascoril D Plus Syrup Sugar Free',
#   'price(₹)': 129.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Phenylephrine (5mg) ',
#   'short_composition2': ' Chlorpheniramine Maleate (2mg) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Loss of appetite, Headache',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 11,
#   'name': 'Aciloc 150 Tablet',
#   'price(₹)': 40.94,
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 30 tablets',
#   'short_composition1': 'Ranitidine (150mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Diarrhea, Gastrointestinal disturbance',
#   'use0': 'Treatment of Gastroesophageal reflux disease (Acid reflux)',
#   'use1': 'Treatment of Peptic ulcer disease',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aralkylamines Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': 'H2 Receptor Blocker'},
#  {'id': 12,
#   'name': 'Alex Syrup',
#   'price(₹)': 129.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Phenylephrine (5mg/5ml) ',
#   'short_composition2': ' Chlorpheniramine Maleate (2mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Loss of appetite, Headache',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 13,
#   'name': 'Anovate Cream',
#   'price(₹)': 134.2,
#   'manufacturer_name': 'USV Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'tube of 20 gm Cream',
#   'short_composition1': 'Phenylephrine (0.10% w/w) ',
#   'short_composition2': ' Beclometasone (0.025% w/w) ',
#   'Consolidated_Side_Effects': 'Application site reactions (burning, irritation, itching and redness)',
#   'use0': 'Treatment of Piles',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'DERMA',
#   'Action Class': None},
#  {'id': 14,
#   'name': 'Augmentin Duo Oral Suspension',
#   'price(₹)': 67.2,
#   'manufacturer_name': 'Glaxo SmithKline Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 30 ml Oral Suspension',
#   'short_composition1': 'Amoxycillin  (200mg) ',
#   'short_composition2': '  Clavulanic Acid (28.5mg)',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Abdominal pain, Diarrhea, Allergy, Skin rash',
#   'use0': 'Treatment of Resistance Tuberculosis (TB)',
#   'use1': 'Treatment of Bacterial infections',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': None},
#  {'id': 15,
#   'name': 'Ambrodil-S Syrup',
#   'price(₹)': 30.2,
#   'manufacturer_name': 'Aristo Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Ambroxol (15mg/5ml) ',
#   'short_composition2': ' Salbutamol (1mg/5ml)',
#   'Consolidated_Side_Effects': 'Headache, Palpitations, Upset stomach, Tremors, Muscle cramp, Allergic reaction, Increased heart rate',
#   'use0': 'Treatment of Cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 16,
#   'name': 'Arkamin Tablet',
#   'price(₹)': 72.65,
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 30 tablets',
#   'short_composition1': 'Clonidine (100mcg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Dizziness, Dryness in mouth, Headache, Nausea, Fatigue, Orthostatic hypotension (sudden lowering of blood pressure on standing), Erectile dysfunction, Enlarged salivary gland',
#   'use0': 'Treatment of Hypertension (high blood pressure)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Imidazoline derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'Alpha 2-adrenoceptors agonist (Central sympatholytics)'},
#  {'id': 17,
#   'name': 'Avomine Tablet',
#   'price(₹)': 55.98,
#   'manufacturer_name': 'Abbott',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Promethazine (25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Unusual production of breast milk in women and men',
#   'use0': 'Treatment of Nausea',
#   'use1': 'Treatment of Vomiting',
#   'use2': 'Treatment of Allergic conditions',
#   'use3': 'Treatment of Motion sickness',
#   'use4': None,
#   'Chemical Class': 'Phenothiazine Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 18,
#   'name': 'Asthakind-DX Syrup Sugar Free',
#   'price(₹)': 70.4,
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 60 ml Syrup',
#   'short_composition1': 'Phenylephrine (5mg/5ml) ',
#   'short_composition2': ' Chlorpheniramine Maleate (2mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Loss of appetite, Headache',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 19,
#   'name': 'Allegra 180mg Tablet',
#   'price(₹)': 251.2,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Fexofenadine (180mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Drowsiness, Dizziness, Nausea',
#   'use0': 'Treatment of Sneezing and runny nose due to allergies',
#   'use1': 'Treatment of Allergic conditions',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Diphenylmethane Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (second Generation)'},
#  {'id': 20,
#   'name': 'Albendazole 400mg Tablet',
#   'price(₹)': 9.58,
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 1 Tablet',
#   'short_composition1': 'Albendazole (400mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Dizziness, Increased liver enzymes, Nausea, Loss of appetite',
#   'use0': 'Treatment of Parasitic infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': '2-Benzimidazolylcarbamic acid esters',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Antiprotozoal agents'},
#  {'id': 21,
#   'name': 'Asthalin Syrup',
#   'price(₹)': 19.04,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Salbutamol (2mg/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Tremors, Headache, Palpitations, Increased heart rate, Muscle cramp',
#   'use0': 'Treatment of Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzyl Alcohols Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Short acting β2-agonists'},
#  {'id': 22,
#   'name': 'Alprax 0.25 Tablet',
#   'price(₹)': 29.0,
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Alprazolam (0.25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Lightheadedness, Drowsiness',
#   'use0': 'Treatment of Anxiety',
#   'use1': 'Treatment of Panic disorder',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzodiazepines Derivative',
#   'Habit Forming': 'Yes',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Benzodiazepines'},
#  {'id': 23,
#   'name': 'Altraday Capsule SR',
#   'price(₹)': 128.0,
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 capsule sr',
#   'short_composition1': 'Aceclofenac (200mg) ',
#   'short_composition2': ' Rabeprazole (20mg)',
#   'Consolidated_Side_Effects': 'Nausea, Flatulence, Indigestion, Diarrhea, Constipation',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 24,
#   'name': 'Ativan 2mg Tablet',
#   'price(₹)': 91.87,
#   'manufacturer_name': 'Pfizer Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 30 tablets',
#   'short_composition1': 'Lorazepam (2mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Fatigue, Balance disorder (loss of balance), Dizziness, Sleepiness',
#   'use0': 'Treatment of Short term anxiety',
#   'use1': 'Treatment of Anxiety disorder',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzodiazepines Derivative',
#   'Habit Forming': 'Yes',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Benzodiazepines'},
#  {'id': 25,
#   'name': 'Ascoril LS Junior Syrup',
#   'price(₹)': 96.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 60 ml Syrup',
#   'short_composition1': 'Ambroxol (15mg/5ml) ',
#   'short_composition2': ' Levosalbutamol (0.5mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Diarrhea, Upset stomach, Stomach pain, Allergic reaction, Dizziness, Headache, Rash, Hives, Tremors, Palpitations, Muscle cramp, Increased heart rate',
#   'use0': 'Treatment of Cough with mucus',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 26,
#   'name': 'Asthalin 100mcg Inhaler',
#   'price(₹)': 157.85,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'packet of 200 MDI Inhaler',
#   'short_composition1': 'Salbutamol (100mcg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Tachycardia, Tremors, Headache, Palpitations, Increased heart rate, Muscle cramp',
#   'use0': 'Treatment of Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzyl Alcohols Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Short acting β2-agonists'},
#  {'id': 27,
#   'name': 'Almox 500 Capsule',
#   'price(₹)': 80.26,
#   'manufacturer_name': 'Alkem Laboratories Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 capsules',
#   'short_composition1': 'Amoxycillin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Rash, Vomiting, Allergic reaction, Nausea, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aminopenicillins Penicillins',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Cell wall active agent -Extended spectrum Penicillin'},
#  {'id': 27,
#   'name': 'Almox 500 Capsule',
#   'price(₹)': 80.26,
#   'manufacturer_name': 'Alkem Laboratories Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 capsules',
#   'short_composition1': 'Amoxycillin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Rash, Vomiting, Allergic reaction, Nausea, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aminopenicillins {Penicillins}',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Cell wall active agent -Extended spectrum Penicillin'},
#  {'id': 28,
#   'name': 'Atarax 10mg Tablet',
#   'price(₹)': 47.91,
#   'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Hydroxyzine (10mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sedation, Nausea, Vomiting, Upset stomach, Constipation',
#   'use0': 'Treatment of Anxiety',
#   'use1': 'Treatment of Skin conditions with inflammation & itching',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Piperazine Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 29,
#   'name': 'Aciloc RD 20 Tablet',
#   'price(₹)': 77.0,
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Domperidone (10mg) ',
#   'short_composition2': ' Omeprazole (20mg)',
#   'Consolidated_Side_Effects': 'Diarrhea, Stomach pain, Dryness in mouth, Headache, Flatulence',
#   'use0': 'Treatment of Gastroesophageal reflux disease (Acid reflux)',
#   'use1': 'Treatment of Peptic ulcer disease',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': None},
#  {'id': 30,
#   'name': 'Aldactone Tablet',
#   'price(₹)': 35.35,
#   'manufacturer_name': 'RPG Life Sciences Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Spironolactone (25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Leg cramps, Dizziness, Drowsiness, Confusion, Breast enlargement in male, Increased creatinine level in blood',
#   'use0': ' Hypertension (high blood pressure)',
#   'use1': ' Edema',
#   'use2': ' Low potassium',
#   'use3': ' Heart failure',
#   'use4': None,
#   'Chemical Class': 'Potassium sparing diuretics',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'Potassium- sparing Diuretics'},
#  {'id': 31,
#   'name': 'Allegra Suspension Raspberry & Vanilla',
#   'price(₹)': 188.78,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Oral Suspension',
#   'short_composition1': 'Fexofenadine (30mg/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Drowsiness, Dizziness, Nausea',
#   'use0': 'Treatment of Sneezing and runny nose due to allergies',
#   'use1': 'Treatment of Allergic conditions',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Diphenylmethane Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (second Generation)'},
#  {'id': 32,
#   'name': 'Atarax Syrup',
#   'price(₹)': 110.25,
#   'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Hydroxyzine (10mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sedation, Nausea, Vomiting, Upset stomach, Constipation',
#   'use0': 'Treatment of Anxiety',
#   'use1': 'Treatment of Skin conditions with inflammation & itching',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Piperazine Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 33,
#   'name': 'Amlokind-AT Tablet',
#   'price(₹)': 44.7,
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Amlodipine (5mg) ',
#   'short_composition2': ' Atenolol (50mg)',
#   'Consolidated_Side_Effects': 'Sleepiness, Headache, Ankle swelling, Flushing (sense of warmth in the face, ears, neck and trunk), Slow heart rate, Palpitations, Nausea, Edema (swelling), Constipation, Tiredness, Cold extremities',
#   'use0': 'Treatment of Hypertension (high blood pressure)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': None},
#  {'id': 34,
#   'name': 'Axcer  90mg Tablet',
#   'price(₹)': 420.0,
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 14 tablets',
#   'short_composition1': 'Ticagrelor (90mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Bleeding, Breathlessness',
#   'use0': ' Prevention of heart attack and stroke',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Triazolopyrimidines',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'BLOOD RELATED',
#   'Action Class': 'P2Y12 inhibitors (ADP receptor)'},
#  {'id': 35,
#   'name': 'Ativan 1mg Tablet',
#   'price(₹)': 75.67,
#   'manufacturer_name': 'Pfizer Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 30 tablets',
#   'short_composition1': 'Lorazepam (1mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Dizziness, Weakness, Sedation, Balance disorder (loss of balance)',
#   'use0': 'Treatment of Short term anxiety',
#   'use1': 'Treatment of Anxiety disorder',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzodiazepines Derivative',
#   'Habit Forming': 'Yes',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Benzodiazepines'},
#  {'id': 36,
#   'name': 'Alkasol Oral Solution',
#   'price(₹)': 122.05,
#   'manufacturer_name': 'Stadmed Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Oral Solution',
#   'short_composition1': 'Disodium Hydrogen Citrate (1.4gm/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Stomach pain, Tiredness, Diarrhea, Nausea, Vomiting, Frequent urge to urinate',
#   'use0': 'Treatment of Gout',
#   'use1': 'Treatment of Kidney stone',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Carboxylic acid derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'UROLOGY',
#   'Action Class': 'Uricosuric agent-gout'},
#  {'id': 37,
#   'name': 'Aldigesic P 100mg/325mg Tablet',
#   'price(₹)': 110.0,
#   'manufacturer_name': 'Alkem Laboratories Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Aceclofenac (100mg) ',
#   'short_composition2': ' Paracetamol (325mg)',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Stomach pain/epigastric pain, Loss of appetite, Heartburn, Diarrhea',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 38,
#   'name': 'Alfoo 10mg Tablet PR',
#   'price(₹)': 687.75,
#   'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 30 Tablet pr',
#   'short_composition1': 'Alfuzosin (10mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Upper respiratory tract infection, Dizziness, Headache, Nausea, Abdominal pain, Impotence',
#   'use0': 'Treatment of Benign prostatic hyperplasia',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Quinazoline Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'UROLOGY',
#   'Action Class': 'Uroselective adrenergic receptor(α1a) antagonist'},
#  {'id': 39,
#   'name': 'Alprax 0.5mg Tablet',
#   'price(₹)': 66.9,
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Alprazolam (0.5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Lightheadedness, Drowsiness',
#   'use0': 'Treatment of Anxiety',
#   'use1': 'Treatment of Panic disorder',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzodiazepines Derivative',
#   'Habit Forming': 'Yes',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Benzodiazepines'},
#  {'id': 40,
#   'name': 'Arachitol 6L Injection',
#   'price(₹)': 407.76,
#   'manufacturer_name': 'Abbott',
#   'type': 'allopathy',
#   'pack_size_label': 'packet of 6 injections',
#   'short_composition1': 'Vitamin D3 (600000IU)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Injection site reactions (pain, swelling, redness), Weakness, Muscle pain, Metallic taste',
#   'use0': 'Treatment of Vitamin D deficiency',
#   'use1': 'Treatment of Osteoporosis',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Vitamin D Derivative [cholecalciferol]',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'VITAMINS MINERALS NUTRIENTS',
#   'Action Class': 'Vitamins'},
#  {'id': 41,
#   'name': 'Anafortan 25 mg/300 mg Tablet',
#   'price(₹)': 124.56,
#   'manufacturer_name': 'Abbott',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Camylofin (25mg) ',
#   'short_composition2': ' Paracetamol (300mg)',
#   'Consolidated_Side_Effects': 'Dryness in mouth, Constipation, Blurred vision, Increased heart rate',
#   'use0': 'Treatment of Abdominal pain',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': None},
#  {'id': 42,
#   'name': 'Alex Junior Syrup',
#   'price(₹)': 95.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 60 ml Syrup',
#   'short_composition1': 'Chlorpheniramine Maleate (2mg/5ml) ',
#   'short_composition2': ' Dextromethorphan Hydrobromide (5mg/5ml)',
#   'Consolidated_Side_Effects': 'Upset stomach, Sleepiness',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 43,
#   'name': 'Azithral 200 Liquid',
#   'price(₹)': 57.25,
#   'manufacturer_name': 'Alembic Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 15 ml Oral Suspension',
#   'short_composition1': 'Azithromycin (200mg/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 44,
#   'name': 'AB Phylline Capsule',
#   'price(₹)': 162.0,
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 capsules',
#   'short_composition1': 'Acebrophylline (100mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Nausea, Headache, Vomiting, Upset stomach, Restlessness',
#   'use0': ' Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Xanthinic Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Theophylline & its derivatives'},
#  {'id': 45,
#   'name': 'Althrocin 500 Tablet',
#   'price(₹)': 110.3,
#   'manufacturer_name': 'Alembic Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Erythromycin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 46,
#   'name': 'Augmentin DDS Suspension',
#   'price(₹)': 173.0,
#   'manufacturer_name': 'Glaxo SmithKline Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 30 ml Oral Suspension',
#   'short_composition1': 'Amoxycillin  (400mg/5ml) ',
#   'short_composition2': '  Clavulanic Acid (57mg/5ml)',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Abdominal pain, Diarrhea, Allergy, Skin rash',
#   'use0': 'Treatment of Resistant Tuberculosis (TB)',
#   'use1': 'Treatment of Bacterial infections',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': None},
#  {'id': 47,
#   'name': 'Azicip 500 Tablet',
#   'price(₹)': 79.43,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 3 tablets',
#   'short_composition1': 'Azithromycin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 48,
#   'name': 'Aldigesic-SP Tablet',
#   'price(₹)': 120.0,
#   'manufacturer_name': 'Alkem Laboratories Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Aceclofenac (100mg) ',
#   'short_composition2': ' Paracetamol (325mg) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Stomach pain, Indigestion, Heartburn, Loss of appetite, Diarrhea',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 49,
#   'name': 'Amoxycillin 500mg Capsule',
#   'price(₹)': 31.9,
#   'manufacturer_name': 'Jagsonpal Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 capsules',
#   'short_composition1': 'Amoxycillin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Rash, Vomiting, Allergic reaction, Nausea, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aminopenicillins {Penicillins}',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Cell wall active agent -Extended spectrum Penicillin'},
#  {'id': 50,
#   'name': 'Asthakind Expectorant Sugar Free',
#   'price(₹)': 64.22,
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 60 ml Expectorant',
#   'short_composition1': 'Guaifenesin (50mg) ',
#   'short_composition2': ' Terbutaline (1.25mg) ',
#   'Consolidated_Side_Effects': 'Nausea, Diarrhea, Bloating, Indigestion, Vomiting, Stomach pain, Sweating, Dizziness, Headache, Skin rash, Hives, Tremors, Increased heart rate',
#   'use0': 'Treatment of Cough with mucus',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 51,
#   'name': 'Acemiz Plus Tablet',
#   'price(₹)': 99.5,
#   'manufacturer_name': 'Lupin Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Aceclofenac (100mg) ',
#   'short_composition2': ' Paracetamol (325mg)',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Stomach pain/epigastric pain, Loss of appetite, Heartburn, Diarrhea',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 52,
#   'name': 'Aceclo Plus Tablet',
#   'price(₹)': 90.85,
#   'manufacturer_name': 'Aristo Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Aceclofenac (100mg) ',
#   'short_composition2': ' Paracetamol (325mg)',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Stomach pain/epigastric pain, Loss of appetite, Heartburn, Diarrhea',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 53,
#   'name': 'Anobliss Cream',
#   'price(₹)': 136.68,
#   'manufacturer_name': 'Samarth Life Sciences Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'tube of 30 gm Rectal Cream',
#   'short_composition1': 'Lidocaine (1.5% w/w) ',
#   'short_composition2': ' Nifedipine (0.3% w/w)',
#   'Consolidated_Side_Effects': 'Anal irritation',
#   'use0': 'Treatment of Anal fissure',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 54,
#   'name': 'Alex Cough Lozenges Lemon Ginger',
#   'price(₹)': 108.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 lozenges',
#   'short_composition1': 'Dextromethorphan Hydrobromide (5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sleepiness, Dizziness, Confusion, Nausea',
#   'use0': ' Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Methyl Analog of Dextrorphan',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Cough suppressants'},
#  {'id': 55,
#   'name': 'Asthalin Respules',
#   'price(₹)': 7.07,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'packet of 2.5 ml Respules',
#   'short_composition1': 'Salbutamol (2.5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Tachycardia, Tremors, Headache, Palpitations, Increased heart rate, Muscle cramp',
#   'use0': 'Treatment of Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Benzyl Alcohols Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'Short acting β2-agonists'},
#  {'id': 56,
#   'name': 'Avil Injection',
#   'price(₹)': 21.17,
#   'manufacturer_name': 'Sanofi India  Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'vial of 10 ml Injection',
#   'short_composition1': 'Pheniramine (22.75mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Sleepiness, Dryness in mouth',
#   'use0': 'Treatment of Allergic conditions',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Pyridines Derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': 'H1 Antihistaminics (First Generation)'},
#  {'id': 57,
#   'name': 'Azee 200mg Dry Syrup',
#   'price(₹)': 52.31,
#   'manufacturer_name': 'Cipla Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 15 ml Oral Suspension',
#   'short_composition1': 'Azithromycin (200mg/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 58,
#   'name': 'Atorva Tablet',
#   'price(₹)': 102.31,
#   'manufacturer_name': 'Zydus Cadila',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Atorvastatin (10mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Dyspepsia, Abdominal pain, Indigestion, Diarrhea, Joint pain, Nasopharyngitis (inflammation of the throat and nasal passages), Nausea, Pain in extremities, Urinary tract infection, Abnormal liver function tests',
#   'use0': ' High cholesterol',
#   'use1': 'Prevention of Heart attack',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Pyrrole & heptanoic acid derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'HMG CoA inhibitors (statins)'},
#  {'id': 59,
#   'name': 'Asthakind-LS Expectorant Cola Sugar Free',
#   'price(₹)': 93.5,
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Expectorant',
#   'short_composition1': 'Ambroxol (30mg/5ml) ',
#   'short_composition2': ' Levosalbutamol (1mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Diarrhea, Upset stomach, Stomach pain, Allergic reaction, Dizziness, Headache, Rash, Hives, Tremors, Palpitations, Muscle cramp, Increased heart rate',
#   'use0': 'Treatment of Cough with mucus',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 60,
#   'name': 'Ascoril LS Drops',
#   'price(₹)': 72.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 15 ml Oral Drops',
#   'short_composition1': 'Ambroxol (7.5mg/ml) ',
#   'short_composition2': ' Levosalbutamol (0.25mg/ml) ',
#   'Consolidated_Side_Effects': 'Vomiting, Diarrhea, Excessive salivation, Fatigue, Headache, Dizziness, Rash, Numbness of extremity, Nausea, Increased heart rate, Stomach discomfort, Palpitations, Tremors, Muscle cramp',
#   'use0': 'Acute Sore throat',
#   'use1': 'Treatment of Cough with mucus',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 61,
#   'name': 'Azmarda 50mg Tablet',
#   'price(₹)': 1092.03,
#   'manufacturer_name': 'J B Chemicals and Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 14 tablets',
#   'short_composition1': 'Sacubitril (24mg) ',
#   'short_composition2': ' Valsartan (26mg)',
#   'Consolidated_Side_Effects': 'Dizziness, Increased potassium level in blood, Fatigue, Hypotension (low blood pressure)',
#   'use0': 'Treatment of Heart failure',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': None},
#  {'id': 62,
#   'name': 'Amixide-H Tablet',
#   'price(₹)': 51.0,
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Amitriptyline (12.5mg) ',
#   'short_composition2': ' Chlordiazepoxide (5mg)',
#   'Consolidated_Side_Effects': 'Constipation, Difficulty in urination, Weight gain, Confusion, Orthostatic hypotension (sudden lowering of blood pressure on standing), Tiredness, Blurred vision, Dryness in mouth, Increased heart rate, Uncoordinated body movements, Depression, Memory impairment',
#   'use0': 'Treatment of Depression',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'Yes',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': None},
#  {'id': 63,
#   'name': 'AB-Flo-N Tablet',
#   'price(₹)': 207.25,
#   'manufacturer_name': 'Lupin Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Acebrophylline (100mg) ',
#   'short_composition2': ' Acetylcysteine (600mg)',
#   'Consolidated_Side_Effects': 'Vomiting, Heartburn, Stomach pain, Upset stomach, Rash, Hives, Itching, Breathing problems, Nasal inflammation, Increased white blood cell count',
#   'use0': 'Treatment of Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 64,
#   'name': 'AF Kit Tablet',
#   'price(₹)': 110.0,
#   'manufacturer_name': 'Systopic Laboratories Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 4 tablets',
#   'short_composition1': 'Azithromycin (1000mg) ',
#   'short_composition2': ' Ornidazole (750mg) ',
#   'Consolidated_Side_Effects': 'Taste change, Vomiting, Headache, Dizziness, Stomach pain, Nausea, Indigestion, Diarrhea, Loss of appetite',
#   'use0': 'Treatment of Syndromic treatment of vaginal discharge',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GYNAECOLOGICAL',
#   'Action Class': None},
#  {'id': 65,
#   'name': 'Amlokind 5 Tablet',
#   'price(₹)': 22.15,
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Amlodipine (5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Fatigue, Nausea, Abdominal pain, Sleepiness',
#   'use0': 'Treatment of Hypertension (high blood pressure)',
#   'use1': 'Prevention of Angina (heart-related chest pain)',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Dihydropyridinecarboxylic acids derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'Calcium channel blockers- Dihydropyridines (DHP)'},
#  {'id': 66,
#   'name': 'Amlong Tablet',
#   'price(₹)': 48.55,
#   'manufacturer_name': 'Micro Labs Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 15 tablets',
#   'short_composition1': 'Amlodipine (5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Fatigue, Nausea, Abdominal pain, Sleepiness',
#   'use0': 'Treatment of Hypertension (high blood pressure)',
#   'use1': 'Prevention of Angina (heart-related chest pain)',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Dihydropyridinecarboxylic acids derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'Calcium channel blockers- Dihydropyridines (DHP)'},
#  {'id': 67,
#   'name': 'Akt 4 Kit',
#   'price(₹)': 24.7,
#   'manufacturer_name': 'Lupin Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'packet of 1 Kit',
#   'short_composition1': 'Isoniazid (300mg) ',
#   'short_composition2': ' Rifampicin (450mg) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Rash, Fever, Dark colored urine, Sweating, Increased sputum production, Salivation, Watery eyes, Peripheral neuropathy (tingling and numbness of feet and hand), Increased liver enzymes, Jaundice, Increased uric acid level in blood, Visual impairment',
#   'use0': 'Treatment of Tuberculosis (TB)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': None},
#  {'id': 68,
#   'name': 'Ascoril D Junior Cough Syrup',
#   'price(₹)': 98.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 60 ml Syrup',
#   'short_composition1': 'Phenylephrine (5mg/5ml) ',
#   'short_composition2': ' Chlorpheniramine Maleate (2mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Loss of appetite, Headache',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 69,
#   'name': 'Amitone 10mg Tablet',
#   'price(₹)': 19.15,
#   'manufacturer_name': 'Intas Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Amitriptyline (10mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Constipation, Dryness in mouth, Orthostatic hypotension (sudden lowering of blood pressure on standing), Weight gain, Aggressive behavior, Nasal congestion (stuffy nose), Sleepiness, Dizziness, Headache, Decreased libido, Nausea, Fatigue, Confusion, Tremors, Speech disorder, Palpitations, Taste change, Paresthesia (tingling or pricking sensation), Abnormality of voluntary movements, Loss of accommodation, Atrioventricular block, Micturition disorders, Erectile dysfunction, Abnormal ECG, Decreased sodium level in blood',
#   'use0': 'Treatment of Depression',
#   'use1': ' Neuropathic pain',
#   'use2': 'Treatment of Migraine',
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Dibenzocycloheptenes Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Tricyclic antidepressants'},
#  {'id': 70,
#   'name': 'Aulin 100mg Tablet',
#   'price(₹)': 50.56,
#   'manufacturer_name': 'Elder Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Nimesulide (100mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Diarrhea',
#   'use0': ' Pain relief',
#   'use1': 'Treatment of Fever',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Diphenylethers Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': "NSAID's-Non-Selective COX 1&2 Inhibitors (Others)"},
#  {'id': 71,
#   'name': 'Amikacin Sulphate 500mg Injection',
#   'price(₹)': 11.87,
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'vial of 2 ml Injection',
#   'short_composition1': 'Amikacin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Increased blood urea, Injection site reactions (pain, swelling, redness)',
#   'use0': ' Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aminoglycosides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'OPHTHAL',
#   'Action Class': 'Aminoglycosides'},
#  {'id': 72,
#   'name': 'Ambrodil-LX Syrup',
#   'price(₹)': 90.85,
#   'manufacturer_name': 'Aristo Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
# ...
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Constipation, Dryness in mouth, Orthostatic hypotension (sudden lowering of blood pressure on standing), Weight gain, Aggressive behavior, Nasal congestion (stuffy nose), Sleepiness, Dizziness, Headache, Decreased libido, Nausea, Fatigue, Confusion, Tremors, Speech disorder, Palpitations, Taste change, Paresthesia (tingling or pricking sensation), Abnormality of voluntary movements, Loss of accommodation, Atrioventricular block, Micturition disorders, Erectile dysfunction, Abnormal ECG, Decreased sodium level in blood',
#   'use0': 'Treatment of Depression',
#   'use1': ' Neuropathic pain',
#   'use2': 'Treatment of Migraine',
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Dibenzocycloheptenes Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Tricyclic antidepressants'},
#  {'id': 950,
#   'name': 'Alex P Paed Drop',
#   'price(₹)': 73.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 15 ml Drop',
#   'short_composition1': 'Chlorpheniramine Maleate (2mg/ml) ',
#   'short_composition2': ' Paracetamol (125mg/ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Headache, Insomnia (difficulty in sleeping), Dizziness, Tachycardia, Palpitations, Fear, Anxiety, Restlessness, Tremors, Weakness, Discomfort when urinating, Hallucination, Convulsion',
#   'use0': 'Treatment of Common cold',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 951,
#   'name': 'Azivent 250 Tablet',
#   'price(₹)': 118.5,
#   'manufacturer_name': 'Aristo Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Azithromycin (250mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  {'id': 952,
#   'name': "Alto's Citrasol Liquid",
#   'price(₹)': 54.0,
#   'manufacturer_name': 'Alto Healthcare Pvt. Ltd.',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Disodium Hydrogen Citrate (1.4gm/5ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Stomach pain, Tiredness, Diarrhea, Nausea, Vomiting, Frequent urge to urinate',
#   'use0': 'Treatment of Gout',
#   'use1': 'Treatment of Kidney stone',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Carboxylic acid derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'UROLOGY',
#   'Action Class': 'Uricosuric agent-gout'},
#  {'id': 953,
#   'name': 'Amorfine Cream',
#   'price(₹)': 394.46,
#   'manufacturer_name': 'Indiabulls pharmaceutical ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'tube of 30 gm Cream',
#   'short_composition1': 'Amorolfine (0.25% w/w)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Blisters on skin, Nail disorder, Skin irritation, Skin rash, Erythema (skin redness)',
#   'use0': ' Fungal nail infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Phenylpropanes derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'DERMA',
#   'Action Class': 'Antifungal Others'},
#  {'id': 954,
#   'name': 'Azapure Tablet',
#   'price(₹)': 118.23,
#   'manufacturer_name': 'Intas Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Azathioprine (50mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Decreased white blood cell count, Increased bleeding tendency, Nausea, Infection, Loss of appetite',
#   'use0': ' Prevention of organ rejection in transplant patients',
#   'use1': 'Treatment of Rheumatoid arthritis',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Nucleoside Analog, and Purines',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI NEOPLASTICS',
#   'Action Class': 'Immunosuppressant- Purine analogs'},
#  {'id': 955,
#   'name': 'Akme-Entoquol Tablet',
#   'price(₹)': 33.0,
#   'manufacturer_name': 'Akme Biotec',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 20 tablets',
#   'short_composition1': 'Loperamide (2mg) ',
#   'short_composition2': ' Beta-Cyclodextrin (10mg)',
#   'Consolidated_Side_Effects': 'Constipation, Nausea, Vomiting, Abdominal pain',
#   'use0': 'Treatment of Diarrhea',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': None},
#  {'id': 956,
#   'name': 'Amrolmac Cream',
#   'price(₹)': 206.25,
#   'manufacturer_name': 'Macleods Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'tube of 15 gm Cream',
#   'short_composition1': 'Amorolfine (0.25% w/w)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Blisters on skin, Nail disorder, Skin irritation, Skin rash, Erythema (skin redness)',
#   'use0': ' Fungal nail infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Phenylpropanes derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'DERMA',
#   'Action Class': 'Antifungal Others'},
#  {'id': 956,
#   'name': 'Amrolmac Cream',
#   'price(₹)': 206.25,
#   'manufacturer_name': 'Macleods Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'tube of 15 gm Cream',
#   'short_composition1': 'Amorolfine (0.25% w/w)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Blisters on skin, Nail disorder, Skin irritation, Skin rash, Erythema (skin redness)',
#   'use0': ' Fungal nail infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Phenylpropanes derivatives',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'DERMA',
#   'Action Class': 'Antifungal Others'},
#  {'id': 957,
#   'name': 'Atherochek 10 Tablet',
#   'price(₹)': 151.3,
#   'manufacturer_name': 'Indoco Remedies Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Atorvastatin (10mg) ',
#   'short_composition2': ' Methylcobalamin (500mcg) ',
#   'Consolidated_Side_Effects': 'Joint pain, Increased liver enzymes, Nausea, Upset stomach, Diarrhea, Muscle pain',
#   'use0': ' High cholesterol',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': None},
#  {'id': 958,
#   'name': 'Axepta 18mg Tablet',
#   'price(₹)': 178.0,
#   'manufacturer_name': 'Intas Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Atomoxetine (18mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Nausea, Vomiting, Sleepiness, Decreased appetite, Abdominal pain, Increased heart rate, High blood pressure',
#   'use0': ' Attention deficit hyperactivity disorder (ADHD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Propylamine Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Sympthatomimmetics-ADHD (Non stimulant)'},
#  {'id': 959,
#   'name': 'Alconil 500mg Tablet',
#   'price(₹)': 30.0,
#   'manufacturer_name': 'Zen Labs India',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 4 tablets',
#   'short_composition1': 'Disulfiram (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Fatigue, Drowsiness, Metallic taste',
#   'use0': 'Treatment of Alcohol addiction',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Carbamate Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'NEURO CNS',
#   'Action Class': 'Alcohol deaddiction'},
#  {'id': 960,
#   'name': 'Ascodex D Syrup',
#   'price(₹)': 129.0,
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Phenylephrine (5mg/5ml) ',
#   'short_composition2': ' Chlorpheniramine Maleate (2mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Loss of appetite, Headache',
#   'use0': 'Treatment of Dry cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 961,
#   'name': 'Angiplat 6.5 Capsule TR',
#   'price(₹)': 207.5,
#   'manufacturer_name': 'Micro Labs Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 25 capsule tr',
#   'short_composition1': 'Nitroglycerin (6.5mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Blurred vision, Decreased blood pressure, Dizziness, Headache, Increased heart rate, Lightheadedness, Paresthesia (tingling or pricking sensation)',
#   'use0': 'Treatment of Angina (heart-related chest pain)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Nitrates {Short acting}',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'NO Donors'},
#  {'id': 962,
#   'name': 'Adfrar Injection',
#   'price(₹)': 25000.0,
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'prefilled syringe of 1 Injection',
#   'short_composition1': 'Adalimumab (40mg/0.8ml)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Sinus inflammation, Rash, Upper respiratory tract infection, Injection site reaction',
#   'use0': ' Ankylosing spondylitis',
#   'use1': ' Rheumatoid arthritis',
#   'use2': ' Psoriasis',
#   'use3': ' Ulcerative colitis',
#   'use4': ' Crohn’s disease',
#   'Chemical Class': 'Monoclonal antibody (mAb)',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI NEOPLASTICS',
#   'Action Class': 'Disease Modifying Anti-Rheumatoid Drugs (DMARDs)- Biologics'},
#  {'id': 963,
#   'name': 'Ambrox T Syrup',
#   'price(₹)': 50.0,
#   'manufacturer_name': 'Bajaj Pharmaceutical',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Syrup',
#   'short_composition1': 'Ambroxol (15mg/5ml) ',
#   'short_composition2': ' Guaifenesin (50mg/5ml) ',
#   'Consolidated_Side_Effects': 'Nausea, Diarrhea, Vomiting, Dizziness, Headache, Rash, Tremors, Increased heart rate, Upper abdominal pain, Urticaria, Itching, Sweating, Changes in serum aminotransferase levels, Bloating, Indigestion',
#   'use0': ' Cough',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 964,
#   'name': 'Aciloc Only Oral Liquid',
#   'price(₹)': 133.98,
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'bottle of 100 ml Liquid',
#   'short_composition1': 'Ranitidine (25mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Diarrhea, Gastrointestinal disturbance',
#   'use0': 'Treatment of Gastroesophageal reflux disease (Acid reflux)',
#   'use1': 'Treatment of Peptic ulcer disease',
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aralkylamines Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'GASTRO INTESTINAL',
#   'Action Class': 'H2 Receptor Blocker'},
#  {'id': 965,
#   'name': 'Azunate 60mg Injection',
#   'price(₹)': 208.24,
#   'manufacturer_name': 'Macleods Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'vial of 1 Injection',
#   'short_composition1': 'Artesunate (60mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Headache, Dizziness, Weakness, Loss of appetite, Injection site reactions (pain, swelling, redness)',
#   'use0': ' Malaria',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Sesquiterpene lactones',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI MALARIALS',
#   'Action Class': 'Antimalarial- Artemisinin and derivatives'},
#  {'id': 966,
#   'name': 'Acton-OR Plus+ Tablet',
#   'price(₹)': 164.9,
#   'manufacturer_name': 'Apex Laboratories Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Paracetamol (325mg) ',
#   'short_composition2': ' Thiocolchicoside (4mg)',
#   'Consolidated_Side_Effects': 'Stomach pain, Diarrhea, Skin rash',
#   'use0': ' Pain due to muscle spasm',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': None},
#  {'id': 967,
#   'name': 'Amikacin 250mg Injection',
#   'price(₹)': 38.7,
#   'manufacturer_name': 'Prem Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'vial of 1 Injection',
#   'short_composition1': 'Amikacin (250mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Increased blood urea, Injection site reactions (pain, swelling, redness)',
#   'use0': ' Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Aminoglycosides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'OPHTHAL',
#   'Action Class': 'Aminoglycosides'},
#  {'id': 968,
#   'name': 'Accardi MR Tablet MR',
#   'price(₹)': 110.0,
#   'manufacturer_name': 'Accilex Diacardo',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablet mr',
#   'short_composition1': 'Trimetazidine (35mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Dizziness, Headache, Nausea, Vomiting, Weakness, Rash, Abdominal pain, Indigestion, Itching, Diarrhea, Hives',
#   'use0': 'Treatment of Angina (heart-related chest pain)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Phenylmethylamines',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'CARDIAC',
#   'Action Class': 'Fatty acid modulator & Sodium channel blocker'},
#  {'id': 969,
#   'name': 'Acenac-SR Tablet',
#   'price(₹)': 82.0,
#   'manufacturer_name': 'Medley Pharmaceuticals',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablet sr',
#   'short_composition1': 'Aceclofenac (200mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Dizziness, Indigestion, Nausea, Abdominal pain, Increased liver enzymes',
#   'use0': ' Pain relief',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Dichlorobenzenes Derivative',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'PAIN ANALGESICS',
#   'Action Class': "NSAID's- Non-Selective COX 1&2 Inhibitors (acetic acid)"},
#  {'id': 970,
#   'name': 'Albutamol Plus Tablet',
#   'price(₹)': 46.16,
#   'manufacturer_name': 'Centaur Pharmaceuticals Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 10 tablets',
#   'short_composition1': 'Salbutamol (NA) ',
#   'short_composition2': ' Etofylline (NA) ',
#   'Consolidated_Side_Effects': 'Nausea, Vomiting, Bloating, Stomach discomfort, Diarrhea, Dizziness, Headache, Sweating, Skin rash, Tremors, Palpitations, Muscle cramp, Restlessness, Increased heart rate',
#   'use0': ' Chronic obstructive pulmonary disease (COPD)',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': None,
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'RESPIRATORY',
#   'Action Class': None},
#  {'id': 971,
#   'name': 'Azirin 500mg Tablet',
#   'price(₹)': 60.59,
#   'manufacturer_name': 'Rhine Biogenics Pvt Ltd',
#   'type': 'allopathy',
#   'pack_size_label': 'strip of 3 tablets',
#   'short_composition1': 'Azithromycin (500mg)',
#   'short_composition2': None,
#   'Consolidated_Side_Effects': 'Vomiting, Nausea, Abdominal pain, Diarrhea',
#   'use0': 'Treatment of Bacterial infections',
#   'use1': None,
#   'use2': None,
#   'use3': None,
#   'use4': None,
#   'Chemical Class': 'Macrolides',
#   'Habit Forming': 'No',
#   'Therapeutic Class': 'ANTI INFECTIVES',
#   'Action Class': 'Macrolides'},
#  ...]

# %%
db = client['ENQUIRY']

# %%
db.list_collection_names()
# Out:
# ['A_Z_medidb']

# %%
collection = db['A_Z_medidb']
batch_size = 500
for i in range(0, len(list_of_dicts), batch_size):
    collection.insert_many(list_of_dicts[i:i+batch_size])
